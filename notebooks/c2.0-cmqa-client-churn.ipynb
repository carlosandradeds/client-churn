# %% [markdown]
# Business Problem
#
# A empresa Top Bank atua na Europa tendo como principal produto uma conta bancária, este produto pode manter o salário do cliente e efetuar pagamentos. Essa conta não tem nenhum custo nos primeiros 12 meses, porém, após esse contra-relógio, o cliente precisa recontratar o banco para os próximos 12 meses e refazer esse processo todos os anos. Recentemente, a equipe de análise notou que a taxa de churn está aumentando.
#
# Como Cientista de Dados, você precisa criar um plano de ação para diminuir o número de clientes churn e mostrar o retorno financeiro da sua solução.
# Além disso, você precisará fornecer um relatório relatando o desempenho de seu modelo e o impacto financeiro de sua solução.
# Perguntas que o CEO e a equipe do Analytics gostariam de ver em seu relatório:
#
# 1. Qual é a atual taxa de Churn do Top Bank?
#
# 2. How does the churn rate vary monthly?
#
# 3. Qual é o desempenho do modelo na classificação de clientes como churns?
#
# 4. Qual é o retorno esperado, em termos de receita, se a empresa utilizar seu modelo para evitar o churn de clientes?
#
#
# Data Fields
#
#
# - **RowNumber:** o número de colunas
# - **CustomerID:** identificador exclusivo de clientes
# - **Surname:** sobrenome do cliente
# - **CreditScore:** pontuação de crédito do cliente para o mercado financeiro
# - **Geography:** o país do cliente
# - **Gender:** o gênero do cliente
# - **Age:** a idade do cliente
# - **Tenure:** número de anos que o cliente está no banco
# - **Balance:** o valor que o cliente tem em sua conta
# - **NumOfProducts:** o número de produtos que o cliente comprou
# - **HasCrCard:** se o cliente tiver cartão de crédito
# - **IsActiveMember:** se o cliente estiver ativo (nos últimos 12 meses)
# - **EstimateSalary:** estimativa do salário anual dos clientes
# - **Exited:** se o cliente for um churn (variável resposta)

# %% [markdown]
# # 0.0 Imports

# %%
import inflection 
import warnings
import random

import scikitplot  as skplt
import pandas      as pd
import numpy       as np
import seaborn     as sns
import xgboost     as xgb

from scipy                   import stats as ss
from scipy.stats             import uniform as sp_randFloat
from scipy.stats             import randint as sp_randInt

from matplotlib              import pyplot as plt

from IPython.core.display    import HTML
from IPython.display         import Image

from sklearn.preprocessing   import RobustScaler, MinMaxScaler, LabelEncoder
from sklearn                 import ensemble        as en
from lightgbm                import LGBMClassifier
from sklearn                 import linear_model    as lm
from sklearn                 import model_selection as ms
from sklearn                 import preprocessing   as pp
from sklearn                 import neighbors       as nh
from sklearn.metrics         import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, precision_recall_curve
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, RandomizedSearchCV
from tabulate                import tabulate


from yellowbrick.classifier  import ConfusionMatrix, ClassificationReport, ROCAUC

from imblearn.combine        import SMOTETomek

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 0.1 Helper Functions

# %%
def jupyter_settings():
        # %matplotlib inline
        
        plt.style.use('bmh')
        plt.rcParams['figure.figsize'] = [15 , 8]
        plt.rcParams['font.size'] = 24
        
        display( HTML( '<style>.container { width:100% !important; }</style>') )
        pd.options.display.max_columns = None
        pd.options.display.max_rows = None
        pd.set_option( 'display.expand_frame_repr', False )
        
        sns.set()
        
def cramer_v( x, y ):
        cm = pd.crosstab( x, y ).to_numpy()
        n = cm.sum()
        r, k = cm.shape
        
        chi2 = ss.chi2_contingency( cm )[0]
        chi2corr = max( 0, chi2 - (k-1)*(r-1)/(n-1) )
        
        kcorr = k - (k-1)**2/(n-1)
        rcorr = r - (r-1)**2/(n-1)
        
        return np.sqrt( (chi2corr/n) / ( min( kcorr-1, rcorr-1 ) ) )
    
    
def cross_validation(data, model, name_model, n_splits, n_repeats, top_k):
    X = data.drop('exited',axis=1)
    y = data['exited']
    cv = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats)
    i = 1
    metrics_k = pd.DataFrame()
    
    for train_index, test_index in cv.split(X, y):
        X_train, X_val = X.iloc[train_index], X.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        print ('\nKFold Number: {}'.format( i ) )
        i+=1
        
        #print('training_lenght:{x_training.shape[0]}\nvalidation_lenght:{x_prim_val.shape[0]}\n\n')
        
        #model training
        ml_model = model.fit(X_train,y_train)
        
        #prediction
        yhat = ml_model.predict_proba(X_val)
        
        #performance
        result_model = table_analysis(y_val,yhat)
        #metrics_k = metrics_k.append(precision_recall_at_k(result_model,top_k))
        metrics_k = pd.concat([metrics_k,precision_recall_at_k(result_model,top_k)],axis=0)
        
    
    
    real_performance = pd.DataFrame({
        #'Name_Model': name_model,
        'Mean_Precision_at_k' : str((np.round((metrics_k['precision_at_k'].mean()),5)))+ '+/-'+str((np.round((metrics_k['precision_at_k'].std()),5))),
        'Mean_Recall_at_k': str((np.round((metrics_k['recall_at_k'].mean()),5)))+ '+/-'+str((np.round((metrics_k['recall_at_k'].std()),5)))
    }, index = [name_model])        
        
    
    return real_performance

def table_analysis(y_val,yhat):
    table = pd.DataFrame(y_val)
    table['customer_id'] = y_val.index + 1
    table['predict_score'] = yhat[:,1].tolist()
    table = table.sort_values('predict_score',ascending=False)
    table = table.reset_index(drop=True)
    table['ranking'] = table.index + 1
    table['acc_pred_score'] = table['exited'].cumsum()/table['exited'].sum()
    table['base'] = table['ranking']/len(table)
    table['baseline'] = table['base'] 
    table['lift'] = table['acc_pred_score'] / table['baseline']
    table['precision_at_k'] = table['exited'].cumsum()/table['ranking']
    table['recall_at_k'] = table['exited'].cumsum()/table['exited'].sum()
    order_cols = ['customer_id','exited','predict_score','ranking','acc_pred_score','base','baseline','lift','precision_at_k','recall_at_k']
    table = table[order_cols]
    
    return table

def precision_recall_at_k (table, k=100):
    #data = data.sort_values('predict_score',ascending=False)
    #data = data.reset_index(drop=True)
    #data['ranking'] = data.index+1
    table['precision_at_k'] = table['exited'].cumsum()/table['ranking']
    table['recall_at_k'] = table['exited'].cumsum()/table['exited'].sum()
    
    return pd.DataFrame({'precision_at_k':table.loc[k-1,'precision_at_k'],'recall_at_k': table.loc[k-1,'recall_at_k']},index=[k])

def precision_recall_at_k_2 (table, k=100):
    #data = data.sort_values('predict_score',ascending=False)
    #data = data.reset_index(drop=True)
    #data['ranking'] = data.index+1
    table['precision_at_k'] = table['exited'].cumsum()/table['ranking']
    table['recall_at_k'] = table['exited'].cumsum()/table['exited'].sum()
    
    return ({table.loc[k-1,'precision_at_k'],table.loc[k-1,'recall_at_k']})

def model_metrics(models, y_test):
    """Calculate Precision, Recall and F1

    Args:
        models[list]: [List of Machine Learning Algorithms]
        y_test: [Target Feature Test DataFrame]

    Returns:
        [DataFrame]: [DataFrame with metrics]
    """

    result_df = []
    for model in models:
        # model prediction
        model_name = type(model).__name__
        yhat = model.predict(x_val)
        yhat_proba = model.predict_proba(x_val)
        yhat_proba = yhat_proba[:, 1]
        accuracy = accuracy_score(y_val, yhat)
        precision = precision_score(y_val, yhat)
        recall = recall_score(y_val, yhat)
        f1 = f1_score(y_val, yhat)
        rocauc = roc_auc_score(y_val, yhat_proba)
        model_metrics = pd.DataFrame( { 'Model Name': model_name,
                                        'Accuracy': accuracy,
                                        'Precision': precision,
                                        'Recall': recall,
                                        'F1-Score': f1,
                                        'ROCAUC': rocauc},  index = [0])
        result_df.append(model_metrics)

    result = pd.concat(result_df)
    
    return result

# %%
jupyter_settings()
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2 Import dataset

# %%
data_raw = pd.read_csv('C:/Users/kaka/Projetos_DS/client-churn/data/raw/churn.csv')

# %% [markdown]
# # 1.0 Data Description

# %%
df1 = data_raw.copy()

# %% [markdown]
# ## 1.1 Data Dimension

# %%
print('Number of Rows: {}'.format(df1.shape[0]))
print('Number of Columns: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 10000
# Number of Columns: 14

# %% [markdown]
# ## 1.2 Data Columns Rename

# %%
cols_old = ['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
            'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
            'IsActiveMember', 'EstimatedSalary', 'Exited']

snakecase = lambda x: inflection.underscore(x)

cols_new = list(map(snakecase, cols_old))

#rename
df1.columns = cols_new

# %%
df1 = df1.drop('row_number', axis=1)

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# customer_id           int64
# surname              object
# credit_score          int64
# geography            object
# gender               object
# age                   int64
# tenure                int64
# balance             float64
# num_of_products       int64
# has_cr_card           int64
# is_active_member      int64
# estimated_salary    float64
# exited                int64
# dtype: object

# %% [markdown]
# ## 1.4 Data Check NA

# %%
df1.isna().sum()
# Out:
# customer_id         0
# surname             0
# credit_score        0
# geography           0
# gender              0
# age                 0
# tenure              0
# balance             0
# num_of_products     0
# has_cr_card         0
# is_active_member    0
# estimated_salary    0
# exited              0
# dtype: int64

# %% [markdown]
# ## 1.5 Data Descriptive

# %%
num_attributes = df1[['customer_id', 'credit_score', 'age', 'tenure', 'balance', 'num_of_products']]
cat_attributes = df1[['geography', 'gender', 'has_cr_card', 'is_active_member', 'exited', 'surname']]

# %% [markdown]
# ### 1.5.1 Numerical Attributes

# %%
#Central Tendency - mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

#dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T
                  
#concat
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = ['attributes,', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#        attributes,         min          max      range          mean       median           std      skew  kurtosis
# 0      customer_id  15565701.0  15815690.00  249989.00  1.569094e+07  15690738.00  71932.589224  0.001149 -1.196113
# 1     credit_score       350.0       850.00     500.00  6.505288e+02       652.00     96.648466 -0.071607 -0.425726
# 2              age        18.0        92.00      74.00  3.892180e+01        37.00     10.487282  1.011320  1.395347
# 3           tenure         0.0        10.00      10.00  5.012800e+00         5.00      2.892030  0.010991 -1.165225
# 4          balance         0.0    250898.09  250898.09  7.648589e+04     97198.54  62394.285254 -0.141109 -1.489412
# 5  num_of_products         1.0         4.00       3.00  1.530200e+00         1.00      0.581625  0.745568  0.582981

# %% [markdown]
# ### 1.5.2 Categorical Attributes

# %%
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# geography              3
# gender                 2
# has_cr_card            2
# is_active_member       2
# exited                 2
# surname             2932
# dtype: int64

# %%
#gender
aux = pd.DataFrame({'absolute': cat_attributes['gender'].value_counts(), 'percent %': cat_attributes['gender'].value_counts(normalize = True) * 100 })
aux
# Out:
#         absolute  percent %
# Male        5457      54.57
# Female      4543      45.43

# %%
#geography
aux = pd.DataFrame({'absolute': cat_attributes['geography'].value_counts(), 'percent %': cat_attributes['geography'].value_counts(normalize = True) * 100 })
aux
# Out:
#          absolute  percent %
# France       5014      50.14
# Germany      2509      25.09
# Spain        2477      24.77

# %%
#has_cr_card
aux = pd.DataFrame({'absolute': cat_attributes['has_cr_card'].value_counts(), 'percent %': cat_attributes['has_cr_card'].value_counts(normalize = True) * 100 })
aux
# Out:
#    absolute  percent %
# 1      7055      70.55
# 0      2945      29.45

# %%
#is_active_member
aux = pd.DataFrame({'absolute': cat_attributes['is_active_member'].value_counts(), 'percent %': cat_attributes['is_active_member'].value_counts(normalize = True) * 100 })
aux
# Out:
#    absolute  percent %
# 1      5151      51.51
# 0      4849      48.49

# %%
#exited
aux = pd.DataFrame({'absolute': cat_attributes['exited'].value_counts(), 'percent %': cat_attributes['exited'].value_counts(normalize = True) * 100 })
aux
# Out:
#    absolute  percent %
# 0      7963      79.63
# 1      2037      20.37

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# # 3.0 Data Filtering

# %%
df3 = df2.copy()

# %% [markdown]
# # 4.0 EDA

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Análise Univariada

# %% [markdown]
# ### 4.1.1 Response Variable

# %%
sns.distplot(df4['exited'], kde=False)
# Out:
# <AxesSubplot:xlabel='exited'>

# %% [markdown]
# ### 4.1.2 Numerical Variable

# %%
num_attributes.hist( bins=25 );

# %% [markdown]
# ### 4.1.3 Categorical Variable

# %%
plt.subplot(2, 2, 1)
sns.countplot(df4['geography'])

plt.subplot(2, 2, 2)
sns.countplot(df4['gender'])

plt.subplot(2, 2, 3)
sns.countplot(df4['has_cr_card'])

plt.subplot(2, 2, 4)
sns.countplot(df4['is_active_member'])
# Out:
# <AxesSubplot:xlabel='is_active_member', ylabel='count'>

# %% [markdown]
# ## 4.2 Análise Bivariada

# %% [markdown]
# ### 4.2.1 H1 Clientes idosos têm mais tendência a serem churn.
#
# **True** Clientes com maior idade, tendem a serem churn

# %%
plt.subplot(1, 2, 1)
aux = (df4[df4['exited'] == 0]['age'])
sns.distplot(aux, kde=True)

plt.subplot(1, 2, 2)
aux = (df4[df4['exited'] == 1]['age'])
sns.distplot(aux, kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
plt.subplot(1, 2, 1)
aux = df4[['age', 'exited']]
sns.boxplot(x='exited', y='age', data=aux)


plt.subplot(1, 2, 2)
aux = df4[['age', 'exited']].groupby('age').mean().reset_index()
sns.regplot(x='age', y='exited', data=aux)
# Out:
# <AxesSubplot:xlabel='age', ylabel='exited'>

# %% [markdown]
# ### 4.2.2 H2 Homens tem mais tendencia a entrar em churn
#
# **True** Mulheres tem mais tendencia a entrar em churn

# %%
aux = df4[['gender', 'exited']].groupby('gender').mean().reset_index()

# display graph
plt.figure(figsize=(12,4))
graph = sns.barplot(y='gender', x='exited', data=aux, palette='dark');
graph.bar_label(graph.containers[0], fmt='%.2f');
plt.xlabel('Gender');
plt.ylabel('Churn Rates');
plt.title('Churn Rates by Gender');

# %% [markdown]
# ### 4.2.3 H3 Clientes com mais de 5 anos de permanência têm uma taxa de churn menor
#
# **False** Os clientes tem a mesma taxa de churn independente da permanencia

# %%
aux = df4[['exited', 'tenure']].groupby('tenure').mean().reset_index()
sns.barplot(x='tenure', y='exited', data=aux);

# %%
plt.subplot(1, 2, 1)
aux = (df4[df4['exited'] == 0]['tenure'])
sns.distplot(aux, kde=True)

plt.subplot(1, 2, 2)
aux = (df4[df4['exited'] == 1]['tenure'])
sns.distplot(aux, kde=True)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Density'>

# %% [markdown]
# ### 4.2.4 H4 Clientes com maior score de crédito tem menor chance de churn
#
# **Verdadeiro** Os clientes coma menores taxas de crédito tem maior chance de churn

# %%
aux = df4[['exited', 'credit_score']].groupby('credit_score').mean().reset_index()

plt.subplot(1, 2, 1)
bins = list(np.arange(250, 850, 50))
aux['credit_score_binned'] = pd.cut(aux['credit_score'], bins=bins)
aux2 = aux[['exited', 'credit_score_binned']].groupby('credit_score_binned').mean().reset_index()
sns.barplot(x='credit_score_binned', y='exited', data=aux2);
plt.xticks(rotation=90);

plt.subplot(1, 2, 2)
sns.regplot(x='credit_score', y='exited', data=aux)
# Out:
# <AxesSubplot:xlabel='credit_score', ylabel='exited'>

# %% [markdown]
# ### 4.2.5 H5 Quanto maior a quantidade de produtos, menor a taxa de churn
#
# **False** Quanto maior a quantidade de produtos, maior a probabilidade de churn

# %%
aux = df4[['num_of_products', 'exited']].groupby('num_of_products').mean().reset_index()

plt.subplot(1, 3, 1)
sns.barplot(x='num_of_products', y='exited', data=aux)

plt.subplot(1, 3, 2)
sns.regplot(x='num_of_products', y='exited', data=aux)

plt.subplot(1, 3, 3)
sns.heatmap(aux.corr(method='pearson'), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.2.5 H6 Clientes com maior valor em conta tem menor chance de entrar em churn
#
# **False** Os clientes com maior valor em conta tem maior chance de churn

# %%
aux = df4[['balance', 'exited']].groupby('balance').mean().reset_index()

plt.subplot(1, 2, 1)
bins = list(np.arange(0, 260000, 5000))
aux['balance_binned'] = pd.cut(aux['balance'], bins=bins)
aux2 = aux[['exited', 'balance_binned']].groupby('balance_binned').mean().reset_index()
sns.barplot(x='balance_binned', y='exited', data=aux2);
plt.xticks(rotation=90);

# %% [markdown]
# ## 4.3 Análise Multivariada

# %% [markdown]
# ### 4.3.1 Numerical Attributes

# %%
num_attributes = df1[['customer_id', 'credit_score', 'age', 'tenure', 'balance', 'num_of_products', 'estimated_salary', 'exited' ]]

correlation = num_attributes.corr(method='pearson')

sns.heatmap(correlation, annot=True);

# %% [markdown]
# ### 4.3.1 Categorical Attributes

# %%
cat_attributes = df4[['geography', 'gender', 'has_cr_card', 'is_active_member', 'exited','surname']]

#only categorical data
a = cat_attributes

#calculate cramer V
a1 = cramer_v(a['geography'], a['geography'])
a2 = cramer_v(a['geography'], a['gender'])
a3 = cramer_v(a['geography'], a['has_cr_card'])
a4 = cramer_v(a['geography'], a['is_active_member'])
a5 = cramer_v(a['geography'], a['surname'])

a6   = cramer_v(a['gender'], a['geography'])
a7   = cramer_v(a['gender'], a['gender'])
a8   = cramer_v(a['gender'], a['has_cr_card'])
a9   = cramer_v(a['gender'], a['is_active_member'])
a10  = cramer_v(a['gender'], a['surname'])

a11  = cramer_v(a['has_cr_card'], a['geography'])
a12  = cramer_v(a['has_cr_card'], a['gender'])
a13  = cramer_v(a['has_cr_card'], a['has_cr_card'])
a14  = cramer_v(a['has_cr_card'], a['is_active_member'])
a15  = cramer_v(a['has_cr_card'], a['surname'])

a16  = cramer_v(a['is_active_member'], a['geography'])
a17  = cramer_v(a['is_active_member'], a['gender'])
a18  = cramer_v(a['is_active_member'], a['has_cr_card'])
a19  = cramer_v(a['is_active_member'], a['is_active_member'])
a20  = cramer_v(a['is_active_member'], a['surname'])

a21  = cramer_v(a['surname'], a['geography'])
a22  = cramer_v(a['surname'], a['gender'])
a23  = cramer_v(a['surname'], a['has_cr_card'])
a24  = cramer_v(a['surname'], a['is_active_member'])
a25  = cramer_v(a['surname'], a['surname'])

#final dataset
d = pd.DataFrame({'geography': [a1, a2, a3, a4, a5],
                  'gender': [a6, a7, a8, a9, a10],
                  'has_cr_card': [a11, a12, a13, a14, a15],
                  'is_active_member': [a16, a17, a18, a19, a20],
                  'surname':[a21, a22, a23, a24, a25]})

d = d.set_index(d.columns)

sns.heatmap(d, annot=True);

# %% [markdown]
# # 5.0 Data Preparation

# %%
df5 = df4.copy()

# %%
df5.head()
# Out:
#    customer_id   surname  credit_score geography  gender  age  tenure    balance  num_of_products  has_cr_card  is_active_member  estimated_salary  exited
# 0     15634602  Hargrave           619    France  Female   42       2       0.00                1            1                 1         101348.88       1
# 1     15647311      Hill           608     Spain  Female   41       1   83807.86                1            0                 1         112542.58       0
# 2     15619304      Onio           502    France  Female   42       8  159660.80                3            1                 0         113931.57       1
# 3     15701354      Boni           699    France  Female   39       1       0.00                2            0                 0          93826.63       0
# 4     15737888  Mitchell           850     Spain  Female   43       2  125510.82                1            1                 1          79084.10       0

# %%
y_train = df5['exited'].copy()

# %%
mms= MinMaxScaler()

# %%
#Numerical preparation

df5['credit_score'] = mms.fit_transform(df5[['credit_score']].values)

df5['age'] = mms.fit_transform(df5[['age']].values)

df5['tenure'] = mms.fit_transform(df5[['tenure']].values)

df5['balance'] = mms.fit_transform(df5[['balance']].values)

df5['estimated_salary'] = mms.fit_transform(df5[['estimated_salary']].values)

df5['num_of_products'] = mms.fit_transform(df5[['balance']].values)

# %%
#categorical preparation

df5['gender'] = df5['gender'].map( {'Female': 0, 'Male': 1} ).astype('int64')


target_encode_geography = df5.groupby( 'geography' )['exited'].mean()
df5.loc[:, 'geography'] = df5['geography'].map( target_encode_geography )

# %%
target_encode_surname = df5.groupby( 'surname' )['exited'].mean()
df5.loc[:, 'surname'] = df5['surname'].map( target_encode_surname )

# %%
df5.head()
# Out:
#    customer_id   surname  credit_score  geography  gender       age  tenure   balance  num_of_products  has_cr_card  is_active_member  estimated_salary  exited
# 0     15634602  1.000000         0.538   0.161548       0  0.324324     0.2  0.000000         0.000000            1                 1          0.506735       1
# 1     15647311  0.117647         0.516   0.166734       0  0.310811     0.1  0.334031         0.334031            0                 1          0.562709       0
# 2     15619304  0.250000         0.304   0.161548       0  0.324324     0.8  0.636357         0.636357            1                 0          0.569654       1
# 3     15701354  0.214286         0.698   0.161548       0  0.283784     0.1  0.000000         0.000000            0                 0          0.469120       0
# 4     15737888  0.100000         1.000   0.166734       0  0.337838     0.2  0.500246         0.500246            1                 1          0.395400       0

# %% [markdown]
# # 6.0 Feature Selection

# %%
x_train_n = df5.drop( ['customer_id', 'exited'], axis=1 )
y_train_n = y_train.values

# %%
# model definition
forest = en.ExtraTreesClassifier( n_estimators=250, random_state=0, n_jobs=-1 )

x_train_n = df5.drop( ['customer_id', 'exited'], axis=1 )
y_train_n = y_train.values
forest.fit( x_train_n, y_train_n )
# Out:
# ExtraTreesClassifier(n_estimators=250, n_jobs=-1, random_state=0)

# %%
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")
df = pd.DataFrame()
for i, j in zip( x_train_n, forest.feature_importances_ ):
    aux = pd.DataFrame( {'feature': i, 'importance': j}, index=[0] )
    df = pd.concat( [df, aux], axis=0 )
    
print( df.sort_values( 'importance', ascending=False ) )

# Plot the impurity-based feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(x_train_n.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(x_train_n.shape[1]), indices)
plt.xlim([-1, x_train_n.shape[1]])
plt.show()
# Out:
# Feature ranking:
#             feature  importance
# 0           surname    0.314134
# 0               age    0.183100
# 0      credit_score    0.089299
# 0  estimated_salary    0.089024
# 0            tenure    0.076457
# 0           balance    0.068195
# 0   num_of_products    0.067851
# 0         geography    0.041844
# 0  is_active_member    0.031172
# 0       has_cr_card    0.021871
# 0            gender    0.017054

# %% [markdown]
# # 7.0 Machine Learning Model

# %%
cols_selected = ['surname','credit_score', 'geography', 'gender', 'age',
                 'tenure', 'balance', 'num_of_products', 'has_cr_card',
                 'is_active_member', 'estimated_salary']

cols_selected_full = ['surname','credit_score', 'geography', 'gender', 'age',
                      'tenure', 'balance', 'num_of_products', 'has_cr_card',
                      'is_active_member', 'estimated_salary', 'exited']

# %%
X = df5.drop( 'exited', axis=1 )
y = df5['exited'].copy()

x_train_b, x_test, y_train_b, y_test = train_test_split( X, y, test_size=0.30 )

df5 = pd.concat( [x_train_b, y_train_b], axis=1 )

# %%
up_sampler = SMOTETomek(random_state=42, n_jobs=-1)

x_train, y_train = up_sampler.fit_resample(x_train_b, y_train_b)

# %%
x_train = x_train[ cols_selected ]

x_val = x_test[ cols_selected ]
y_val = y_test

# %%
df7 = df5[cols_selected_full]

# %% [markdown]
# ## 7.1 Models Training and Validation

# %% [markdown]
# ### 7.1.1 KNN Classifier

# %%
params = {
    'n_neighbors':  [3,5,8,15],
    'weights':  ['uniform', 'distance'], 
    'algorithm': ['ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [20,30,40],
    'p': [1,2]
}
MAX_EVAL = 5

# %%
knn_m = pd.DataFrame()
hp_list = pd.DataFrame()


for i in range(MAX_EVAL):
    hp = {k: random.sample(v,1)[0] for k,v in params.items()}
    hp_list = hp_list.append(hp,ignore_index=True)
    print(hp)
    knn_model =  nh.KNeighborsClassifier( n_neighbors = hp['n_neighbors'],
                                          weights = hp['weights'],
                                          algorithm= hp['algorithm'],
                                          leaf_size= hp['leaf_size'],
                                          p = hp['p'])
         
    knn_cv = cross_validation(df7, knn_model,'KNN Classifier - '+str(i),5,2,200)
    
    knn_m = knn_m.append(knn_cv)
    print(knn_m)
    
    
knn_m
# Out:
# {'n_neighbors': 5, 'weights': 'uniform', 'algorithm': 'ball_tree', 'leaf_size': 30, 'p': 2}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                    Mean_Precision_at_k   Mean_Recall_at_k
# KNN Classifier - 0     0.5825+/-0.0285  0.55003+/-0.02653
# {'n_neighbors': 3, 'weights': 'distance', 'algorithm': 'ball_tree', 'leaf_size': 20, 'p': 1}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                    Mean_Precision_at_k   Mean_Recall_at_k
# KNN Classifier - 0     0.5825+/-0.0285  0.55003+/-0.02653
# KNN Classifier - 1    0.5695+/-0.02291  0.53778+/-0.02184
# {'n_neighbors': 5, 'weights': 'uniform', 'algorithm': 'ball_tree', 'leaf_size': 30, 'p': 1}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                    Mean_Precision_at_k   Mean_Recall_at_k
# KNN Classifier - 0     0.5825+/-0.0285  0.55003+/-0.02653
# KNN Classifier - 1    0.5695+/-0.02291  0.53778+/-0.02184
# KNN Classifier - 2    0.6005+/-0.02006  0.56703+/-0.01829
# {'n_neighbors': 5, 'weights': 'uniform', 'algorithm': 'ball_tree', 'leaf_size': 40, 'p': 1}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                    Mean_Precision_at_k   Mean_Recall_at_k
# KNN Classifier - 0     0.5825+/-0.0285  0.55003+/-0.02653
# KNN Classifier - 1    0.5695+/-0.02291  0.53778+/-0.02184
# KNN Classifier - 2    0.6005+/-0.02006  0.56703+/-0.01829
# KNN Classifier - 3    0.6015+/-0.01473  0.56799+/-0.01399
# {'n_neighbors': 3, 'weights': 'uniform', 'algorithm': 'ball_tree', 'leaf_size': 20, 'p': 1}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                    Mean_Precision_at_k   Mean_Recall_at_k
# KNN Classifier - 0     0.5825+/-0.0285  0.55003+/-0.02653
# KNN Classifier - 1    0.5695+/-0.02291  0.53778+/-0.02184
# KNN Classifier - 2    0.6005+/-0.02006  0.56703+/-0.01829
# KNN Classifier - 3    0.6015+/-0.01473  0.56799+/-0.01399
# KNN Classifier - 4      0.569+/-0.0239  0.53729+/-0.02236
#                    Mean_Precision_at_k   Mean_Recall_at_k
# KNN Classifier - 0     0.5825+/-0.0285  0.55003+/-0.02653
# KNN Classifier - 1    0.5695+/-0.02291  0.53778+/-0.02184
# KNN Classifier - 2    0.6005+/-0.02006  0.56703+/-0.01829
# KNN Classifier - 3    0.6015+/-0.01473  0.56799+/-0.01399
# KNN Classifier - 4      0.569+/-0.0239  0.53729+/-0.02236

# %%
#find best k
Ks = 15

mean_rcc = np.zeros((Ks-1))

for n in range(9,Ks):
    
    #Train Model and Predict  
    knn_model = nh.KNeighborsClassifier(n_neighbors = n).fit(x_train,y_train)
    yhat = knn_model.predict(x_val)
    mean_rcc[n-1] = balanced_accuracy_score(y_val, yhat)

# %%
plt.plot(range(1,Ks),mean_rcc,'g')
plt.legend(('Precision', ), loc = 'center right' )
plt.xlabel('Number of Neighbors')
plt.tight_layout()
plt.show()

# %%
# model definition
knn_model = nh.KNeighborsClassifier( n_neighbors=10 )

# model training
knn_model.fit( x_train, y_train )

# model prediction
yhat_knn = knn_model.predict_proba( x_val )

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_val, yhat_knn );

# %% [markdown]
# ### 7.1.2 Logistic Regression

# %%
params = {
    'penalty':  ['l2', 'none'],
    'C':  [0.5, 1, 10, 100], 
    'solver': ['newton-cg', 'lbfgs', 'sag'],
    'class_weight': [None, 'balanced']
}

MAX_EVAL = 5

# %%
lr_m = pd.DataFrame()
hp_list = pd.DataFrame()


for i in range(MAX_EVAL):
    hp = {k: random.sample(v,1)[0] for k,v in params.items()}
    hp_list = hp_list.append(hp,ignore_index=True)
    print(hp)
    lr_model =  lm.LogisticRegression( penalty = hp['penalty'],
                                       C= hp['C'],
                                       solver= hp['solver'],
                                       class_weight= hp['class_weight'],
                                     )
         
    lr_cv = cross_validation(df7 , lr_model,'Logistic Regression - '+str(i),5,2,200)
    
    lr_m = lr_m.append(lr_cv)
    print(lr_m)
    
    
lr_m
# Out:
# {'penalty': 'none', 'C': 100, 'solver': 'sag', 'class_weight': 'balanced'}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                         Mean_Precision_at_k  Mean_Recall_at_k
# Logistic Regression - 0     0.657+/-0.01767  0.6204+/-0.01665
# {'penalty': 'none', 'C': 1, 'solver': 'newton-cg', 'class_weight': 'balanced'}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                         Mean_Precision_at_k   Mean_Recall_at_k
# Logistic Regression - 0     0.657+/-0.01767   0.6204+/-0.01665
# Logistic Regression - 1    0.6555+/-0.02455  0.61896+/-0.02266
# {'penalty': 'none', 'C': 0.5, 'solver': 'newton-cg', 'class_weight': 'balanced'}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                         Mean_Precision_at_k   Mean_Recall_at_k
# Logistic Regression - 0     0.657+/-0.01767   0.6204+/-0.01665
# Logistic Regression - 1    0.6555+/-0.02455  0.61896+/-0.02266
# Logistic Regression - 2     0.658+/-0.03039  0.62137+/-0.02948
# {'penalty': 'none', 'C': 0.5, 'solver': 'lbfgs', 'class_weight': 'balanced'}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                         Mean_Precision_at_k   Mean_Recall_at_k
# Logistic Regression - 0     0.657+/-0.01767   0.6204+/-0.01665
# Logistic Regression - 1    0.6555+/-0.02455  0.61896+/-0.02266
# Logistic Regression - 2     0.658+/-0.03039  0.62137+/-0.02948
# Logistic Regression - 3    0.6575+/-0.02031  0.62086+/-0.01896
# {'penalty': 'none', 'C': 10, 'solver': 'lbfgs', 'class_weight': 'balanced'}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                         Mean_Precision_at_k   Mean_Recall_at_k
# Logistic Regression - 0     0.657+/-0.01767   0.6204+/-0.01665
# Logistic Regression - 1    0.6555+/-0.02455  0.61896+/-0.02266
# Logistic Regression - 2     0.658+/-0.03039  0.62137+/-0.02948
# Logistic Regression - 3    0.6575+/-0.02031  0.62086+/-0.01896
# Logistic Regression - 4    0.6555+/-0.01571  0.61897+/-0.01434
#                         Mean_Precision_at_k   Mean_Recall_at_k
# Logistic Regression - 0     0.657+/-0.01767   0.6204+/-0.01665
# Logistic Regression - 1    0.6555+/-0.02455  0.61896+/-0.02266
# Logistic Regression - 2     0.658+/-0.03039  0.62137+/-0.02948
# Logistic Regression - 3    0.6575+/-0.02031  0.62086+/-0.01896
# Logistic Regression - 4    0.6555+/-0.01571  0.61897+/-0.01434

# %%
# model definition
lr_model = lm.LogisticRegression( random_state=42 ) 

# model training
lr_model.fit( x_train, y_train )

# model prediction
yhat_lr = lr_model.predict_proba( x_val )

# %%
 # Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_val, yhat_lr );

# %%
#Scikitplot library is there to help
skplt.metrics.plot_lift_curve( y_val, yhat_lr );

# %% [markdown]
# ### 7.1.3 Extra trees Classifier

# %%
params = { 'n_estimators':[250,500,750],
           'max_depth':[3,5,7],
           'min_samples_split':  [2,3],
           'min_samples_leaf': [1,2],
           'class_weight': [None, 'balanced','balanced_subsample']
}

MAX_EVAL = 5

# %%
et_m = pd.DataFrame()
hp_list = pd.DataFrame()


for i in range(MAX_EVAL):
    hp = {k: random.sample(v,1)[0] for k,v in params.items()}
    hp_list = hp_list.append(hp,ignore_index=True)
    print(hp)
    et_model = en.ExtraTreesClassifier(n_estimators = hp['n_estimators'],
                                       max_depth = hp['max_depth'],
                                       min_samples_split= hp['min_samples_split'],
                                       min_samples_leaf= hp['min_samples_leaf'],
                                       class_weight = hp['class_weight'],
                                       random_state = 25,
                                       n_jobs=-1)
         
    et_cv = cross_validation(df7,et_model,'Extra Trees Classifier - '+str(i),5,2,200)
    
    et_m = et_m.append(et_cv)
    print(et_m)
    
    
et_m
# Out:
# {'n_estimators': 750, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'class_weight': None}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                            Mean_Precision_at_k  Mean_Recall_at_k
# Extra Trees Classifier - 0     0.637+/-0.04036  0.6015+/-0.03795
# {'n_estimators': 250, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'class_weight': None}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                            Mean_Precision_at_k   Mean_Recall_at_k
# Extra Trees Classifier - 0     0.637+/-0.04036   0.6015+/-0.03795
# Extra Trees Classifier - 1     0.638+/-0.02263  0.60247+/-0.02194
# {'n_estimators': 250, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'class_weight': 'balanced'}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                            Mean_Precision_at_k   Mean_Recall_at_k
# Extra Trees Classifier - 0     0.637+/-0.04036   0.6015+/-0.03795
# Extra Trees Classifier - 1     0.638+/-0.02263  0.60247+/-0.02194
# Extra Trees Classifier - 2     0.673+/-0.02163  0.63552+/-0.02106
# {'n_estimators': 750, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 2, 'class_weight': 'balanced'}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                            Mean_Precision_at_k   Mean_Recall_at_k
# Extra Trees Classifier - 0     0.637+/-0.04036   0.6015+/-0.03795
# Extra Trees Classifier - 1     0.638+/-0.02263  0.60247+/-0.02194
# Extra Trees Classifier - 2     0.673+/-0.02163  0.63552+/-0.02106
# Extra Trees Classifier - 3    0.6855+/-0.02976  0.64734+/-0.02899
# {'n_estimators': 250, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'class_weight': 'balanced'}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                            Mean_Precision_at_k   Mean_Recall_at_k
# Extra Trees Classifier - 0     0.637+/-0.04036   0.6015+/-0.03795
# Extra Trees Classifier - 1     0.638+/-0.02263  0.60247+/-0.02194
# Extra Trees Classifier - 2     0.673+/-0.02163  0.63552+/-0.02106
# Extra Trees Classifier - 3    0.6855+/-0.02976  0.64734+/-0.02899
# Extra Trees Classifier - 4      0.64+/-0.02494  0.60435+/-0.02367
#                            Mean_Precision_at_k   Mean_Recall_at_k
# Extra Trees Classifier - 0     0.637+/-0.04036   0.6015+/-0.03795
# Extra Trees Classifier - 1     0.638+/-0.02263  0.60247+/-0.02194
# Extra Trees Classifier - 2     0.673+/-0.02163  0.63552+/-0.02106
# Extra Trees Classifier - 3    0.6855+/-0.02976  0.64734+/-0.02899
# Extra Trees Classifier - 4      0.64+/-0.02494  0.60435+/-0.02367

# %%
# model definition
et = en.ExtraTreesClassifier( n_estimators=500, n_jobs=-1,
                              random_state=42, max_depth=7 ) 

# model training
et.fit( x_train, y_train )

# model prediction
yhat_et = et.predict_proba( x_val )

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_val, yhat_et );

# %%
 #Scikitplot library is there to help
skplt.metrics.plot_lift_curve( y_val, yhat_et );

# %%
'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 1, 'class_weight': 'balanced_subsample'

# %% [markdown]
# ### 7.1.4 XGBoost Classifier

# %%
params = { 'n_estimators':  [100, 200, 300, 400, 500],
           'max_depth': [3,5,9], 
           'scale_pos_weight': [1,7.15, 100]
}

MAX_EVAL = 5

# %%
xgb_m = pd.DataFrame()
hp_list = pd.DataFrame()


for i in range(MAX_EVAL):
    hp = {k: random.sample(v,1)[0] for k,v in params.items()}
    hp_list = hp_list.append(hp,ignore_index=True)
    print(hp)
    xgb_model = xgb.XGBClassifier(  objective='binary:logistic',
                                    n_estimators = hp['n_estimators'],
                                    max_depth = hp['max_depth'],
                                    scale_pos_weight = hp['scale_pos_weight'],
                                    n_jobs=-1)
         
    xgb_cv = cross_validation(df7,xgb_model,'XGBoost Classifier - '+str(i),5,2,200)
    
    xgb_m = xgb_m.append(xgb_cv)
    print(xgb_m)
    
    
xgb_m
# Out:
# {'n_estimators': 100, 'max_depth': 9, 'scale_pos_weight': 100}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                        Mean_Precision_at_k   Mean_Recall_at_k
# XGBoost Classifier - 0    0.6885+/-0.02358  0.65014+/-0.02222
# {'n_estimators': 200, 'max_depth': 3, 'scale_pos_weight': 7.15}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                        Mean_Precision_at_k   Mean_Recall_at_k
# XGBoost Classifier - 0    0.6885+/-0.02358  0.65014+/-0.02222
# XGBoost Classifier - 1    0.6875+/-0.01586  0.64922+/-0.01577
# {'n_estimators': 300, 'max_depth': 3, 'scale_pos_weight': 7.15}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                        Mean_Precision_at_k   Mean_Recall_at_k
# XGBoost Classifier - 0    0.6885+/-0.02358  0.65014+/-0.02222
# XGBoost Classifier - 1    0.6875+/-0.01586  0.64922+/-0.01577
# XGBoost Classifier - 2     0.665+/-0.02646   0.62793+/-0.0243
# {'n_estimators': 100, 'max_depth': 5, 'scale_pos_weight': 100}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                        Mean_Precision_at_k   Mean_Recall_at_k
# XGBoost Classifier - 0    0.6885+/-0.02358  0.65014+/-0.02222
# XGBoost Classifier - 1    0.6875+/-0.01586  0.64922+/-0.01577
# XGBoost Classifier - 2     0.665+/-0.02646   0.62793+/-0.0243
# XGBoost Classifier - 3     0.669+/-0.02366  0.63173+/-0.02239
# {'n_estimators': 500, 'max_depth': 9, 'scale_pos_weight': 7.15}
#
# KFold Number: 1
#
# KFold Number: 2
#
# KFold Number: 3
#
# KFold Number: 4
#
# KFold Number: 5
#
# KFold Number: 6
#
# KFold Number: 7
#
# KFold Number: 8
#
# KFold Number: 9
#
# KFold Number: 10
#                        Mean_Precision_at_k   Mean_Recall_at_k
# XGBoost Classifier - 0    0.6885+/-0.02358  0.65014+/-0.02222
# XGBoost Classifier - 1    0.6875+/-0.01586  0.64922+/-0.01577
# XGBoost Classifier - 2     0.665+/-0.02646   0.62793+/-0.0243
# XGBoost Classifier - 3     0.669+/-0.02366  0.63173+/-0.02239
# XGBoost Classifier - 4      0.689+/-0.0141  0.65063+/-0.01426
#                        Mean_Precision_at_k   Mean_Recall_at_k
# XGBoost Classifier - 0    0.6885+/-0.02358  0.65014+/-0.02222
# XGBoost Classifier - 1    0.6875+/-0.01586  0.64922+/-0.01577
# XGBoost Classifier - 2     0.665+/-0.02646   0.62793+/-0.0243
# XGBoost Classifier - 3     0.669+/-0.02366  0.63173+/-0.02239
# XGBoost Classifier - 4      0.689+/-0.0141  0.65063+/-0.01426

# %%
# model definition
model_xgb = xgb.XGBClassifier(objective='binary:logistic',
                              random_state=17,
                              n_jobs=-1,
                              max_depth = 5,
                              n_estimators=300)

#model training
model_xgb.fit( x_train, y_train )

# prediction
yhat_xgb = model_xgb.predict_proba( x_val )

# %%
skplt.metrics.plot_cumulative_gain( y_val, yhat_xgb );

# %%
#Scikitplot library is there to help
skplt.metrics.plot_lift_curve( y_val, yhat_xgb );

# %% [markdown]
# ### 7.1.5 LGBM Classifier

# %%
model_lgbm=LGBMClassifier(n_estimators=1100, n_jobs=-1, random_state=42)

#model training
model_lgbm.fit( x_train, y_train )

# prediction
yhat_lgbm = model_lgbm.predict_proba( x_val )

# %%
model_lgbm=LGBMClassifier(colsample_bytree=0.45088109299621176, min_child_samples=100,
                          min_child_weight=0.01, n_estimators=1100, num_leaves=47,
                          random_state=42, reg_alpha=5, reg_lambda=20, scale_pos_weight=1,
                        subsample=0.9159516161223393)

#model training
model_lgbm.fit( x_train, y_train )

# prediction
yhat_lgbm = model_lgbm.predict_proba( x_val )

# %%
skplt.metrics.plot_cumulative_gain( y_val, yhat_lgbm );

# %%
 #Scikitplot library is there to help
skplt.metrics.plot_lift_curve( y_val, yhat_lgbm );

# %% [markdown]
# ### 7.1.6 Metrics Comparison

# %%
models = [ knn_model, lr_model, et, model_xgb, model_lgbm]
model_metrics(models, y_test)
# Out:
#              Model Name  Accuracy  Precision    Recall  F1-Score    ROCAUC
# 0  KNeighborsClassifier  0.813333   0.546742  0.616613  0.579580  0.832529
# 0    LogisticRegression  0.824667   0.562657  0.717252  0.630618  0.869843
# 0  ExtraTreesClassifier  0.829000   0.581062  0.646965  0.612245  0.859092
# 0         XGBClassifier  0.863667   0.696915  0.613419  0.652506  0.882903
# 0        LGBMClassifier  0.870667   0.728846  0.605431  0.661431  0.900646

# %% [markdown]
# ### 7.1.6.1 Confusion Matrix

# %%
fig, axes = plt.subplots(3, 2, figsize=(15,10))

fig.suptitle('Model Comparasion')

cm_viz = ConfusionMatrix(knn_model,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[0][0])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

cm_viz = ConfusionMatrix(lr_model,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[0][1])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

cm_viz = ConfusionMatrix(et,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[1][0])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

cm_viz = ConfusionMatrix(model_xgb,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[1][1])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

cm_viz = ConfusionMatrix(model_lgbm,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[2][0])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

# %% [markdown]
# ### 7.1.6.2 Classification Report

# %%
fig, axes = plt.subplots(3, 2, figsize=(15,10))

fig.suptitle('Model Comparasion')

cm_viz = ClassificationReport(knn_model,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[0][0])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

cm_viz = ClassificationReport(lr_model,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[0][1])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

cm_viz = ClassificationReport(et,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[1][0])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

cm_viz = ClassificationReport(model_xgb,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[1][1])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

cm_viz = ClassificationReport(model_lgbm,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[2][0])
cm_viz.fit(x_train, y_train)  
cm_viz.score(x_val, y_val)
cm_viz.finalize()

# %% [markdown]
# ### 7.1.6.3 Cumulative Gain Comparative

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2,figsize=(25, 15))
fig.suptitle('Cumulative Gain', fontsize = 15)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.35)

skplt.metrics.plot_cumulative_gain(y_val, yhat_knn, title = 'K-Nearest Neighbors', ax = ax1)

skplt.metrics.plot_cumulative_gain(y_val, yhat_lr, title = 'Linear Model',ax = ax2)

skplt.metrics.plot_cumulative_gain(y_val, yhat_et, title = 'Extra Tree', ax = ax3)

skplt.metrics.plot_cumulative_gain(y_val, yhat_xgb, title = 'XGBoost', ax = ax4)

skplt.metrics.plot_cumulative_gain(y_val, yhat_lgbm, title = 'LGBM', ax = ax5)
# Out:
# <AxesSubplot:title={'center':'LGBM'}, xlabel='Percentage of sample', ylabel='Gain'>

# %% [markdown]
# ### 7.1.6.4 Lift Curve Comparative

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2,figsize=(25, 15))
fig.suptitle('Cumulative Gain', fontsize = 15)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.35)

skplt.metrics.plot_lift_curve(y_val, yhat_knn, title = 'K-Nearest Neighbors', ax = ax1)

skplt.metrics.plot_lift_curve(y_val, yhat_lr, title = 'Linear Model',ax = ax2)

skplt.metrics.plot_lift_curve(y_val, yhat_et, title = 'Extra Tree', ax = ax3)

skplt.metrics.plot_lift_curve(y_val, yhat_xgb, title = 'XGBoost', ax = ax4)

skplt.metrics.plot_lift_curve(y_val, yhat_lgbm, title = 'LGBM', ax = ax5)
# Out:
# <AxesSubplot:title={'center':'LGBM'}, xlabel='Percentage of sample', ylabel='Lift'>

# %% [markdown]
# ### 7.1.6.4 ROC Comparative

# %%
fig, axes = plt.subplots(2, 3, figsize=(25,15))

fig.suptitle('ROC Curve Analysis')

rc_viz = ROCAUC(knn_model, classes=['not churn', 'churn'], micro=False, macro=False, ax=axes[0][0])
rc_viz.fit(x_val, y_val)  
rc_viz.score(x_val, y_val)
rc_viz.finalize()

rc_viz = ROCAUC(lr_model, classes=['not churn', 'churn'], micro=False, macro=False, ax=axes[0][1])
rc_viz.fit(x_val, y_val)  
rc_viz.score(x_val, y_val)
rc_viz.finalize()

rc_viz = ROCAUC(et, classes=['not churn', 'churn'], micro=False, macro=False, ax=axes[0][2])
rc_viz.fit(x_val, y_val)  
rc_viz.score(x_val, y_val)
rc_viz.finalize()

rc_viz = ROCAUC(model_xgb, classes=['not churn', 'churn'], micro=False, macro=False, ax=axes[1][0])
rc_viz.fit(x_val, y_val)  
rc_viz.score(x_val, y_val)
rc_viz.finalize()

rc_viz = ROCAUC(model_lgbm, classes=['not churn', 'churn'], micro=False, macro=False, ax=axes[1][1])
rc_viz.fit(x_val, y_val)  
rc_viz.score(x_val, y_val)
rc_viz.finalize()

# %% [markdown]
# # 8.0 HYPERPARAMETER FINE TUNING

# %%
# define evaluation
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %%
param={'num_leaves': sp_randInt(6, 50), 
       'min_child_samples': sp_randInt(100, 500), 
       'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
       'subsample': sp_randFloat(loc=0.2, scale=0.8), 
       'colsample_bytree': sp_randFloat(loc=0.4, scale=0.6),
       'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
       'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100],
       'scale_pos_weight':[1,2,6,12]}

# %%
# define search
search = RandomizedSearchCV(model_lgbm, param_distributions= param, n_iter=500, n_jobs=-1, cv=cv, random_state=1)

# %%
search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1),
#                    estimator=LGBMClassifier(colsample_bytree=0.45088109299621176,
#                                             min_child_samples=100,
#                                             min_child_weight=0.01,
#                                             n_estimators=1100, num_leaves=47,
#                                             random_state=42, reg_alpha=5,
#                                             reg_lambda=20, scale_pos_weight=1,
#                                             subsample=0.9159516161223393),
#                    n_iter=500, n_jobs=-1,
#                    param_distribu...
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000143C6227B80>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'scale_pos_weight': [1, 2, 6, 12],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000143C6233160>},
#                    random_state=1)

# %%
print("\n The best estimator across ALL searched params:\n", search.best_estimator_)
print("\n The best score across ALL searched params:\n", search.best_score_)
print("\n The best parameters across ALL searched params:\n", search.best_params_)
# Out:
#  The best estimator across ALL searched params:
#  LGBMClassifier(colsample_bytree=0.42817229075013036, min_child_samples=473,
#                min_child_weight=10.0, n_estimators=1100, num_leaves=23,
#                random_state=42, reg_alpha=10, reg_lambda=5, scale_pos_weight=1,
#                subsample=0.25107550888001273)
#
#  The best score across ALL searched params:
#  0.8765416666666667
#
#  The best parameters across ALL searched params:
#  {'colsample_bytree': 0.42817229075013036, 'min_child_samples': 473, 'min_child_weight': 10.0, 'num_leaves': 23, 'reg_alpha': 10, 'reg_lambda': 5, 'scale_pos_weight': 1, 'subsample': 0.25107550888001273}

# %% [markdown]
# # 9.0 Perfomance Metrics

# %% [markdown]
# # 11.0 Business Traduction

# %% [markdown]
# # 12.0 Deploy Model
